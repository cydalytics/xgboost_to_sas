# %% [markdown]
# ## Import packages and data

# %%
# import packages
import pandas as pd
import numpy as np
import os 
import re

from sklearn import datasets
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle

import m2cgen as m2c

import warnings
warnings.filterwarnings("ignore")

# %%
# import data
iris = datasets.load_iris()
X = iris.data
Y = iris.target

# %% [markdown]
# ## Train a simple model

# %%
# split data into train and test sets
seed = 2020
test_size = 0.3
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# [01:37:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=24, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ## Convert XGBoost model to VBA

# %%
code = m2c.export_to_visual_basic(model, function_name = 'pred')

# %%
print(code)
# Out:
# Module Model
# Function pred(ByRef inputVector() As Double) As Double()
#     Dim var0 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var0 = -0.21827246
#     Else
#         var0 = 0.42043796
#     End If
#     Dim var1 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var1 = -0.19534391
#     Else
#         var1 = 0.2908748
#     End If
#     Dim var2 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var2 = -0.17986836
#     Else
#         var2 = 0.23301946
#     End If
#     Dim var3 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var3 = -0.16835201
#     Else
#         var3 = 0.20049937
#     End If
#     Dim var4 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var4 = -0.15951659
#     Else
#         var4 = 0.17969704
#     End If
#     Dim var5 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var5 = -0.15227905
#     Else
#         var5 = 0.16499345
#     End If
#     Dim var6 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var6 = -0.14613919
#     Else
#         var6 = 0.1536592
#     End If
#     Dim var7 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var7 = -0.14011411
#     Else
#         var7 = 0.14420119
#     End If
#     Dim var8 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var8 = -0.13456865
#     Else
#         var8 = 0.1357663
#     End If
#     Dim var9 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var9 = -0.12861697
#     Else
#         var9 = 0.12785625
#     End If
#     Dim var10 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var10 = -0.122534
#     Else
#         var10 = 0.120318964
#     End If
#     Dim var11 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var11 = -0.116333105
#     Else
#         var11 = 0.112760454
#     End If
#     Dim var12 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var12 = -0.11009326
#     Else
#         var12 = 0.10522488
#     End If
#     Dim var13 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var13 = -0.10321718
#     Else
#         var13 = 0.09802485
#     End If
#     Dim var14 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var14 = -0.09705321
#     Else
#         var14 = 0.09108403
#     End If
#     Dim var15 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var15 = -0.09126147
#     Else
#         var15 = 0.08483632
#     End If
#     Dim var16 As Double
#     If (inputVector(2)) >= (2.45) Then
#         var16 = -0.085976176
#     Else
#         var16 = 0.08029441
#     End If
#     Dim var17 As Double
#     If (inputVector(2)) >= (3.15) Then
#         var17 = -0.08047648
#     Else
#         var17 = 0.074691966
#     End If
#     Dim var18 As Double
#     var18 = Math.Exp((0.5) + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((var0) + (var1)) + (var2)) + (var3)) + (var4)) + (var5)) + (var6)) + (var7)) + (var8)) + (var9)) + (var10)) + (var11)) + (var12)) + (var13)) + (var14)) + (var15)) + (var16)) + (var17)) + (-0.005524611)) + (-0.0043015457)) + (-0.0034188137)) + (-0.002750235)) + (-0.002255812)) + (-0.0032246502)) + (-0.003928394)) + (-0.0044095414)) + (-0.004755646)) + (-0.005153919)) + (-0.005334354)) + (-0.0053935996)) + (-0.0055099125)) + (-0.005602908)) + (-0.0056739687)) + (-0.005725721)) + (-0.0057591596)) + (-0.0057757483)) + (-0.0057780943)) + (-0.0057664923)) + (-0.0057425257)) + (-0.005706845)) + (-0.005661765)) + (-0.0055862796)) + (-0.0055016503)) + (-0.005409422)) + (-0.0043303967)) + (-0.004363139)) + (-0.0043741623)) + (-0.0043655857)) + (-0.0034215322)) + (-0.0034440104)) + (-0.0034392953)) + (-0.0025525708)) + (-0.0026320452)) + (-0.0026799599)) + (-0.0018942085)) + (-0.002010829)) + (-0.0013254483)) + (-0.0014932072)) + (-0.0008871359)) + (-0.0010909127)) + (-0.00054876786)) + (-0.00077746244)) + (-0.00047311842)) + (-0.00078150653)) + (-0.0002991066)) + (-0.00053850515)) + (-0.00009780034)) + (-0.0003481089)) + (-0.000114589035)) + (0.00021802777)) + (-0.000056490986)) + (0.0003075727)) + (0.000033897595)) + (0.0003761813)) + (0.00010550783)) + (0.00039097446)) + (0.00052621064)) + (0.0002485128)) + (0.00050681765)) + (0.00024063908)) + (0.00048712498)) + (0.00059920363)) + (0.00033187374)) + (0.0005932419)) + (0.0007816312)) + (0.00049697823)) + (0.00059309823)) + (0.00077377027)) + (0.000499179)) + (0.00071924354)) + (0.00045862453)) + (0.0006752837)) + (0.00073895155)) + (0.0008862725)) + (0.0006093266)) + (0.0007892524)) + (0.00053137186)) + (0.0006919573)) + (0.0007431938)) + (0.0004984731)))
#     Dim var19 As Double
#     If (inputVector(1)) >= (2.95) Then
#         If (inputVector(2)) >= (3.15) Then
#             If (inputVector(3)) >= (1.7) Then
#                 var19 = -0.20412374
#             Else
#                 var19 = 0.3122449
#             End If
#         Else
#             var19 = -0.210219
#         End If
#     Else
#         If (inputVector(3)) >= (1.7) Then
#             var19 = -0.1894737
#         Else
#             If (inputVector(2)) >= (4.8500004) Then
#                 var19 = 0.12857142
#             Else
#                 var19 = 0.4141593
#             End If
#         End If
#     End If
#     Dim var20 As Double
#     If (inputVector(1)) >= (2.95) Then
#         If (inputVector(2)) >= (3.15) Then
#             If (inputVector(3)) >= (1.7) Then
#                 var20 = -0.18108536
#             Else
#                 If (inputVector(0)) >= (6.8) Then
#                     var20 = 0.080876015
#                 Else
#                     var20 = 0.25359514
#                 End If
#             End If
#         Else
#             var20 = -0.18699098
#         End If
#     Else
#         If (inputVector(3)) >= (1.7) Then
#             var20 = -0.16725719
#         Else
#             var20 = 0.277371
#         End If
#     End If
#     Dim var21 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var21 = -0.17242625
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var21 = -0.03711913
#             Else
#                 var21 = 0.24106967
#             End If
#         Else
#             var21 = -0.17066373
#         End If
#     End If
#     Dim var22 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var22 = -0.15979621
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var22 = -0.032142717
#             Else
#                 var22 = 0.2057186
#             End If
#         Else
#             var22 = -0.15819389
#         End If
#     End If
#     Dim var23 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var23 = -0.14951265
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var23 = -0.032499813
#             Else
#                 var23 = 0.18413201
#             End If
#         Else
#             var23 = -0.14792646
#         End If
#     End If
#     Dim var24 As Double
#     If (inputVector(1)) >= (2.95) Then
#         If (inputVector(2)) >= (3.15) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var24 = -0.13963485
#             Else
#                 var24 = 0.117164016
#             End If
#         Else
#             var24 = -0.13886009
#         End If
#     Else
#         If (inputVector(3)) >= (1.7) Then
#             var24 = -0.11100679
#         Else
#             If (inputVector(0)) >= (6.25) Then
#                 var24 = 0.054723445
#             Else
#                 var24 = 0.16924205
#             End If
#         End If
#     End If
#     Dim var25 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var25 = -0.1329814
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var25 = -0.036223307
#             Else
#                 var25 = 0.15914293
#             End If
#         Else
#             var25 = -0.13036871
#         End If
#     End If
#     Dim var26 As Double
#     If (inputVector(1)) >= (2.95) Then
#         If (inputVector(2)) >= (3.15) Then
#             If (inputVector(3)) >= (1.55) Then
#                 var26 = -0.11139763
#             Else
#                 var26 = 0.11225922
#             End If
#         Else
#             var26 = -0.122088864
#         End If
#     Else
#         If (inputVector(3)) >= (1.7) Then
#             var26 = -0.0902426
#         Else
#             If (inputVector(0)) >= (6.25) Then
#                 var26 = 0.029444167
#             Else
#                 var26 = 0.1507426
#             End If
#         End If
#     End If
#     Dim var27 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var27 = -0.11815263
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var27 = -0.030736469
#             Else
#                 var27 = 0.14295922
#             End If
#         Else
#             var27 = -0.11385156
#         End If
#     End If
#     Dim var28 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var28 = -0.11094109
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var28 = -0.02325417
#             Else
#                 var28 = 0.13578343
#             End If
#         Else
#             var28 = -0.10563578
#         End If
#     End If
#     Dim var29 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (5.0) Then
#             var29 = -0.1234254
#         Else
#             If (inputVector(2)) >= (2.75) Then
#                 var29 = 0.09414416
#             Else
#                 var29 = -0.09751318
#             End If
#         End If
#     Else
#         var29 = 0.09731874
#     End If
#     Dim var30 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (5.0) Then
#             var30 = -0.11583073
#         Else
#             If (inputVector(2)) >= (2.75) Then
#                 var30 = 0.08469428
#             Else
#                 var30 = -0.0896282
#             End If
#         End If
#     Else
#         var30 = 0.089641325
#     End If
#     Dim var31 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var31 = -0.092850104
#     Else
#         If (inputVector(2)) >= (2.45) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var31 = -0.012017109
#             Else
#                 var31 = 0.11651696
#             End If
#         Else
#             var31 = -0.08211787
#         End If
#     End If
#     Dim var32 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (5.0) Then
#             var32 = -0.10497374
#         Else
#             If (inputVector(2)) >= (3.8) Then
#                 var32 = 0.069721475
#             Else
#                 var32 = -0.069488145
#             End If
#         End If
#     Else
#         var32 = 0.0801942
#     End If
#     Dim var33 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (5.0) Then
#             var33 = -0.09839965
#         Else
#             If (inputVector(2)) >= (4.25) Then
#                 var33 = 0.059869114
#             Else
#                 var33 = -0.049647257
#             End If
#         End If
#     Else
#         var33 = 0.071882054
#     End If
#     Dim var34 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (5.0) Then
#             var34 = -0.09231917
#         Else
#             var34 = 0.011245044
#         End If
#     Else
#         var34 = 0.06456286
#     End If
#     Dim var35 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (5.0) Then
#             var35 = -0.08673477
#         Else
#             var35 = 0.012041473
#         End If
#     Else
#         var35 = 0.058143985
#     End If
#     Dim var36 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (4.8500004) Then
#             var36 = -0.067586765
#         Else
#             var36 = 0.0070128157
#         End If
#     Else
#         var36 = 0.054344207
#     End If
#     Dim var37 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (4.8500004) Then
#             var37 = -0.06299968
#         Else
#             var37 = 0.005813309
#         End If
#     Else
#         var37 = 0.05105127
#     End If
#     Dim var38 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (4.75) Then
#             var38 = -0.049909513
#         Else
#             var38 = 0.0017067876
#         End If
#     Else
#         var38 = 0.047009006
#     End If
#     Dim var39 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (4.75) Then
#             var39 = -0.045884546
#         Else
#             var39 = -0.000008603191
#         End If
#     Else
#         var39 = 0.044970986
#     End If
#     Dim var40 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(2)) >= (4.75) Then
#             var40 = -0.04232024
#         Else
#             var40 = -0.0014069994
#         End If
#     Else
#         var40 = 0.04300546
#     End If
#     Dim var41 As Double
#     If (inputVector(1)) >= (2.75) Then
#         If (inputVector(0)) >= (6.25) Then
#             var41 = -0.0045899716
#         Else
#             var41 = -0.03636634
#         End If
#     Else
#         var41 = 0.04110777
#     End If
#     Dim var42 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var42 = -0.033298276
#     Else
#         var42 = 0.03073641
#     End If
#     Dim var43 As Double
#     If (inputVector(1)) >= (2.75) Then
#         var43 = -0.022811672
#     Else
#         var43 = 0.03659306
#     End If
#     Dim var44 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var44 = -0.028586287
#     Else
#         var44 = 0.02800061
#     End If
#     Dim var45 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var45 = -0.02701611
#     Else
#         var45 = 0.026413469
#     End If
#     Dim var46 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var46 = -0.024131697
#     Else
#         var46 = 0.024225306
#     End If
#     Dim var47 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var47 = -0.022957405
#     Else
#         var47 = 0.022967465
#     End If
#     Dim var48 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var48 = -0.021356972
#     Else
#         var48 = 0.021369683
#     End If
#     Dim var49 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var49 = -0.020398248
#     Else
#         var49 = 0.020367254
#     End If
#     Dim var50 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var50 = -0.019496819
#     Else
#         var50 = 0.01942316
#     End If
#     Dim var51 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var51 = -0.01864721
#     Else
#         var51 = 0.018531451
#     End If
#     Dim var52 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var52 = -0.01784496
#     Else
#         var52 = 0.017687792
#     End If
#     Dim var53 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var53 = -0.017085994
#     Else
#         var53 = 0.016888155
#     End If
#     Dim var54 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var54 = -0.016366743
#     Else
#         var54 = 0.016129572
#     End If
#     Dim var55 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var55 = -0.015684122
#     Else
#         var55 = 0.015409181
#     End If
#     Dim var56 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var56 = -0.0150354
#     Else
#         var56 = 0.014724416
#     End If
#     Dim var57 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var57 = -0.014418123
#     Else
#         var57 = 0.014073373
#     End If
#     Dim var58 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var58 = -0.013830242
#     Else
#         var58 = 0.013454114
#     End If
#     Dim var59 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var59 = -0.013269678
#     Else
#         var59 = 0.012864648
#     End If
#     Dim var60 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var60 = -0.012643063
#     Else
#         var60 = 0.012141587
#     End If
#     Dim var61 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var61 = -0.01205027
#     Else
#         var61 = 0.011471621
#     End If
#     Dim var62 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var62 = -0.010150731
#     Else
#         var62 = 0.013071419
#     End If
#     Dim var63 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var63 = -0.012406148
#     Else
#         var63 = 0.011910836
#     End If
#     Dim var64 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var64 = -0.011757467
#     Else
#         var64 = 0.011176818
#     End If
#     Dim var65 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var65 = -0.011150015
#     Else
#         var65 = 0.010503451
#     End If
#     Dim var66 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var66 = -0.009147625
#     Else
#         var66 = 0.011766563
#     End If
#     Dim var67 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var67 = -0.011285052
#     Else
#         var67 = 0.010670243
#     End If
#     Dim var68 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var68 = -0.0104749445
#     Else
#         var68 = 0.009851719
#     End If
#     Dim var69 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var69 = -0.008586614
#     Else
#         var69 = 0.0110758655
#     End If
#     Dim var70 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var70 = -0.010187396
#     Else
#         var70 = 0.009699955
#     End If
#     Dim var71 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var71 = -0.009445694
#     Else
#         var71 = 0.008931544
#     End If
#     Dim var72 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var72 = -0.008249849
#     Else
#         var72 = 0.010653057
#     End If
#     Dim var73 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var73 = -0.009195565
#     Else
#         var73 = 0.008784805
#     End If
#     Dim var74 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var74 = -0.007705495
#     Else
#         var74 = 0.010022174
#     End If
#     Dim var75 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var75 = -0.008920336
#     Else
#         var75 = 0.008559105
#     End If
#     Dim var76 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var76 = -0.0072737522
#     Else
#         var76 = 0.00948766
#     End If
#     Dim var77 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var77 = -0.00862771
#     Else
#         var77 = 0.008285984
#     End If
#     Dim var78 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var78 = -0.006921405
#     Else
#         var78 = 0.009029352
#     End If
#     Dim var79 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var79 = -0.008324347
#     Else
#         var79 = 0.007987079
#     End If
#     Dim var80 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var80 = -0.007871958
#     Else
#         var80 = 0.007605633
#     End If
#     Dim var81 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var81 = -0.0077557596
#     Else
#         var81 = 0.0073122545
#     End If
#     Dim var82 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var82 = -0.006510421
#     Else
#         var82 = 0.008418651
#     End If
#     Dim var83 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var83 = -0.00777872
#     Else
#         var83 = 0.007430695
#     End If
#     Dim var84 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var84 = -0.0062455563
#     Else
#         var84 = 0.008077477
#     End If
#     Dim var85 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var85 = -0.00747978
#     Else
#         var85 = 0.0071417065
#     End If
#     Dim var86 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var86 = -0.007054187
#     Else
#         var86 = 0.0067576785
#     End If
#     Dim var87 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var87 = -0.007107707
#     Else
#         var87 = 0.0063773366
#     End If
#     Dim var88 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var88 = -0.0072453627
#     Else
#         var88 = 0.006713987
#     End If
#     Dim var89 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var89 = -0.005951236
#     Else
#         var89 = 0.007440034
#     End If
#     Dim var90 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var90 = -0.0069288206
#     Else
#         var90 = 0.006462772
#     End If
#     Dim var91 As Double
#     If (inputVector(2)) >= (4.75) Then
#         var91 = -0.0057346295
#     Else
#         var91 = 0.007212196
#     End If
#     Dim var92 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var92 = -0.0066279736
#     Else
#         var92 = 0.006210318
#     End If
#     Dim var93 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var93 = -0.006680352
#     Else
#         var93 = 0.0059011765
#     End If
#     Dim var94 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var94 = -0.00641546
#     Else
#         var94 = 0.0059461687
#     End If
#     Dim var95 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var95 = -0.0063848663
#     Else
#         var95 = 0.0058331015
#     End If
#     Dim var96 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var96 = -0.006519892
#     Else
#         var96 = 0.0056075505
#     End If
#     Dim var97 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var97 = -0.0061121043
#     Else
#         var97 = 0.0054961126
#     End If
#     Dim var98 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var98 = -0.0062804963
#     Else
#         var98 = 0.005331184
#     End If
#     Dim var99 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var99 = -0.00611864
#     Else
#         var99 = 0.0055057844
#     End If
#     Dim var100 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var100 = -0.0058476245
#     Else
#         var100 = 0.0052049495
#     End If
#     Dim var101 As Double
#     If (inputVector(2)) >= (4.8500004) Then
#         var101 = -0.0054073753
#     Else
#         var101 = 0.0059557236
#     End If
#     Dim var102 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var102 = -0.005775638
#     Else
#         var102 = 0.0048974715
#     End If
#     Dim var103 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var103 = -0.005794904
#     Else
#         var103 = 0.0051862155
#     End If
#     Dim var104 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var104 = -0.0056100246
#     Else
#         var104 = 0.0050377995
#     End If
#     Dim var105 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var105 = -0.0056587416
#     Else
#         var105 = 0.0047248425
#     End If
#     Dim var106 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var106 = -0.005509358
#     Else
#         var106 = 0.0048817163
#     End If
#     Dim var107 As Double
#     If (inputVector(2)) >= (4.8500004) Then
#         var107 = -0.0049915086
#     Else
#         var107 = 0.0054499186
#     End If
#     Dim var108 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var108 = -0.0052451305
#     Else
#         var108 = 0.0047048037
#     End If
#     Dim var109 As Double
#     If (inputVector(2)) >= (4.8500004) Then
#         var109 = -0.0048227385
#     Else
#         var109 = 0.0053271577
#     End If
#     Dim var110 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var110 = -0.005009591
#     Else
#         var110 = 0.0045543583
#     End If
#     Dim var111 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var111 = -0.0052086543
#     Else
#         var111 = 0.0043845773
#     End If
#     Dim var112 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var112 = -0.005186406
#     Else
#         var112 = 0.0046561235
#     End If
#     Dim var113 As Double
#     If (inputVector(2)) >= (4.8500004) Then
#         var113 = -0.004448584
#     Else
#         var113 = 0.004879616
#     End If
#     Dim var114 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var114 = -0.0049228747
#     Else
#         var114 = 0.0044552675
#     End If
#     Dim var115 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var115 = -0.0050548674
#     Else
#         var115 = 0.0042359494
#     End If
#     Dim var116 As Double
#     If (inputVector(0)) >= (6.25) Then
#         var116 = -0.0047040326
#     Else
#         var116 = 0.004205803
#     End If
#     Dim var117 As Double
#     If (inputVector(1)) >= (2.95) Then
#         var117 = -0.0046814047
#     Else
#         var117 = 0.004182419
#     End If
#     Dim var118 As Double
#     If (inputVector(2)) >= (4.8500004) Then
#         var118 = -0.0043212525
#     Else
#         var118 = 0.004731095
#     End If
#     Dim var119 As Double
#     var119 = Math.Exp((0.5) + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((var19) + (var20)) + (var21)) + (var22)) + (var23)) + (var24)) + (var25)) + (var26)) + (var27)) + (var28)) + (var29)) + (var30)) + (var31)) + (var32)) + (var33)) + (var34)) + (var35)) + (var36)) + (var37)) + (var38)) + (var39)) + (var40)) + (var41)) + (var42)) + (var43)) + (var44)) + (var45)) + (var46)) + (var47)) + (var48)) + (var49)) + (var50)) + (var51)) + (var52)) + (var53)) + (var54)) + (var55)) + (var56)) + (var57)) + (var58)) + (var59)) + (var60)) + (var61)) + (var62)) + (var63)) + (var64)) + (var65)) + (var66)) + (var67)) + (var68)) + (var69)) + (var70)) + (var71)) + (var72)) + (var73)) + (var74)) + (var75)) + (var76)) + (var77)) + (var78)) + (var79)) + (var80)) + (var81)) + (var82)) + (var83)) + (var84)) + (var85)) + (var86)) + (var87)) + (var88)) + (var89)) + (var90)) + (var91)) + (var92)) + (var93)) + (var94)) + (var95)) + (var96)) + (var97)) + (var98)) + (var99)) + (var100)) + (var101)) + (var102)) + (var103)) + (var104)) + (var105)) + (var106)) + (var107)) + (var108)) + (var109)) + (var110)) + (var111)) + (var112)) + (var113)) + (var114)) + (var115)) + (var116)) + (var117)) + (var118)))
#     Dim var120 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var120 = 0.42206898
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var120 = 0.12857142
#         Else
#             var120 = -0.21779363
#         End If
#     End If
#     Dim var121 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var121 = 0.29245776
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var121 = 0.11548449
#         Else
#             var121 = -0.19506966
#         End If
#     End If
#     Dim var122 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var122 = 0.23459488
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var122 = 0.110459164
#         Else
#             var122 = -0.17962503
#         End If
#     End If
#     Dim var123 As Double
#     If (inputVector(2)) >= (4.75) Then
#         If (inputVector(3)) >= (1.7) Then
#             var123 = 0.20165354
#         Else
#             If (inputVector(0)) >= (6.55) Then
#                 var123 = 0.035918195
#             Else
#                 var123 = -0.002120249
#             End If
#         End If
#     Else
#         var123 = -0.16714881
#     End If
#     Dim var124 As Double
#     If (inputVector(2)) >= (4.75) Then
#         If (inputVector(3)) >= (1.7) Then
#             var124 = 0.1806804
#         Else
#             If (inputVector(0)) >= (6.55) Then
#                 var124 = 0.03683346
#             Else
#                 var124 = -0.0038339198
#             End If
#         End If
#     Else
#         var124 = -0.15801106
#     End If
#     Dim var125 As Double
#     If (inputVector(2)) >= (4.75) Then
#         If (inputVector(3)) >= (1.7) Then
#             var125 = 0.16593829
#         Else
#             var125 = 0.019427221
#         End If
#     Else
#         var125 = -0.15039223
#     End If
#     Dim var126 As Double
#     If (inputVector(2)) >= (4.75) Then
#         If (inputVector(3)) >= (1.7) Then
#             var126 = 0.15514049
#         Else
#             var126 = 0.018677209
#         End If
#     Else
#         var126 = -0.14384772
#     End If
#     Dim var127 As Double
#     If (inputVector(2)) >= (4.75) Then
#         If (inputVector(1)) >= (2.75) Then
#             If (inputVector(2)) >= (5.0) Then
#                 var127 = 0.1629031
#             Else
#                 var127 = 0.014899884
#             End If
#         Else
#             var127 = -0.0037306617
#         End If
#     Else
#         var127 = -0.13729754
#     End If
#     Dim var128 As Double
#     If (inputVector(2)) >= (4.75) Then
#         If (inputVector(1)) >= (2.75) Then
#             var128 = 0.1353838
#         Else
#             var128 = -0.0062334556
#         End If
#     Else
#         var128 = -0.1311339
#     End If
#     Dim var129 As Double
#     If (inputVector(2)) >= (4.8500004) Then
#         If (inputVector(1)) >= (2.75) Then
#             var129 = 0.13454688
#         Else
#             var129 = -0.011915565
#         End If
#     Else
#         var129 = -0.11783707
#     End If
#     Dim var130 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var130 = 0.12492787
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var130 = 0.036514416
#         Else
#             var130 = -0.123543926
#         End If
#     End If
#     Dim var131 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var131 = 0.1185313
#     Else
#         If (inputVector(0)) >= (6.25) Then
#             var131 = 0.020319015
#         Else
#             var131 = -0.1256014
#         End If
#     End If
#     Dim var132 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var132 = 0.1124286
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var132 = 0.028851861
#         Else
#             var132 = -0.1117734
#         End If
#     End If
#     Dim var133 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var133 = 0.10507546
#     Else
#         If (inputVector(0)) >= (6.25) Then
#             var133 = 0.025969665
#         Else
#             var133 = -0.11468511
#         End If
#     End If
#     Dim var134 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var134 = 0.09938078
#     Else
#         If (inputVector(0)) >= (6.25) Then
#             var134 = 0.022141764
#         Else
#             var134 = -0.10712744
#         End If
#     End If
#     Dim var135 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var135 = 0.094023526
#     Else
#         If (inputVector(0)) >= (6.25) Then
#             var135 = 0.018630145
#         Else
#             var135 = -0.100098945
#         End If
#     End If
#     Dim var136 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var136 = 0.088826604
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var136 = 0.02379664
#         Else
#             var136 = -0.09160408
#         End If
#     End If
#     Dim var137 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var137 = 0.08399659
#     Else
#         If (inputVector(2)) >= (5.0) Then
#             var137 = 0.0198199
#         Else
#             var137 = -0.08659977
#         End If
#     End If
#     Dim var138 As Double
#     If (inputVector(3)) >= (1.7) Then
#         var138 = 0.07945747
#     Else
#         If (inputVector(0)) >= (6.25) Then
#             var138 = 0.014234061
#         Else
#             var138 = -0.086219266
#         End If
#     End If
#     Dim var139 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var139 = 0.056224484
#     Else
#         var139 = -0.05822058
#     End If
#     Dim var140 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var140 = 0.051960308
#     Else
#         var140 = -0.05478737
#     End If
#     Dim var141 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var141 = 0.048160266
#     Else
#         var141 = -0.051507387
#     End If
#     Dim var142 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var142 = 0.044765294
#     Else
#         var142 = -0.048380338
#     End If
#     Dim var143 As Double
#     If (inputVector(0)) >= (6.1499996) Then
#         var143 = 0.042006496
#     Else
#         var143 = -0.048374478
#     End If
#     Dim var144 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var144 = 0.04312884
#     Else
#         var144 = -0.04476531
#     End If
#     Dim var145 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var145 = 0.040548287
#     Else
#         var145 = -0.042045474
#     End If
#     Dim var146 As Double
#     If (inputVector(0)) >= (6.1499996) Then
#         var146 = 0.03782676
#     Else
#         var146 = -0.042320237
#     End If
#     Dim var147 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var147 = 0.03899815
#     Else
#         var147 = -0.038873903
#     End If
#     Dim var148 As Double
#     If (inputVector(3)) >= (1.55) Then
#         var148 = 0.03592317
#     Else
#         var148 = -0.038325332
#     End If
#     Dim var149 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var149 = 0.03611918
#     Else
#         var149 = -0.035577055
#     End If
#     Dim var150 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var150 = 0.03423064
#     Else
#         var150 = -0.03313821
#     End If
#     Dim var151 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var151 = 0.03245664
#     Else
#         var151 = -0.03086154
#     End If
#     Dim var152 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var152 = 0.030789543
#     Else
#         var152 = -0.028738016
#     End If
#     Dim var153 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var153 = 0.029221699
#     Else
#         var153 = -0.026758851
#     End If
#     Dim var154 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var154 = 0.027746823
#     Else
#         var154 = -0.024915457
#     End If
#     Dim var155 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var155 = 0.026358254
#     Else
#         var155 = -0.023199474
#     End If
#     Dim var156 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var156 = 0.025050567
#     Else
#         var156 = -0.021602811
#     End If
#     Dim var157 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var157 = 0.023818111
#     Else
#         var157 = -0.020117808
#     End If
#     Dim var158 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var158 = 0.022655703
#     Else
#         var158 = -0.01873721
#     End If
#     Dim var159 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var159 = 0.021558635
#     Else
#         var159 = -0.017453903
#     End If
#     Dim var160 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var160 = 0.01705505
#     Else
#         var160 = -0.011839308
#     End If
#     Dim var161 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var161 = 0.016322859
#     Else
#         var161 = -0.01097905
#     End If
#     Dim var162 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var162 = 0.015618752
#     Else
#         var162 = -0.010186777
#     End If
#     Dim var163 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var163 = 0.018722648
#     Else
#         var163 = -0.014093797
#     End If
#     Dim var164 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var164 = 0.0128751155
#     Else
#         var164 = -0.008817958
#     End If
#     Dim var165 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var165 = 0.012440304
#     Else
#         var165 = -0.008168368
#     End If
#     Dim var166 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var166 = 0.012007318
#     Else
#         var166 = -0.0075733773
#     End If
#     Dim var167 As Double
#     If (inputVector(2)) >= (5.05) Then
#         var167 = 0.011578177
#     Else
#         var167 = -0.0070278803
#     End If
#     Dim var168 As Double
#     If (inputVector(2)) >= (4.95) Then
#         var168 = 0.013901628
#     Else
#         var168 = -0.013933337
#     End If
#     Dim var169 As Double
#     var169 = Math.Exp((0.5) + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((var120) + (var121)) + (var122)) + (var123)) + (var124)) + (var125)) + (var126)) + (var127)) + (var128)) + (var129)) + (var130)) + (var131)) + (var132)) + (var133)) + (var134)) + (var135)) + (var136)) + (var137)) + (var138)) + (var139)) + (var140)) + (var141)) + (var142)) + (var143)) + (var144)) + (var145)) + (var146)) + (var147)) + (var148)) + (var149)) + (var150)) + (var151)) + (var152)) + (var153)) + (var154)) + (var155)) + (var156)) + (var157)) + (var158)) + (var159)) + (var160)) + (var161)) + (var162)) + (var163)) + (var164)) + (var165)) + (var166)) + (var167)) + (0.0020890676)) + (0.002167549)) + (0.0022100194)) + (0.0014535759)) + (0.0015829625)) + (0.001671069)) + (0.0010004609)) + (0.00115871)) + (0.00058170274)) + (0.0007864849)) + (0.00027943132)) + (0.00051410426)) + (0.000060563903)) + (0.00031364217)) + (var168)) + (0.00036175954)) + (-0.000050552477)) + (0.0001988802)) + (-0.00017846926)) + (0.000077999415)) + (-0.000043270826)) + (-0.00022329079)) + (0.000023552982)) + (-0.00031417116)) + (-0.00006350542)) + (-0.0003788344)) + (-0.00012786238)) + (-0.000285355)) + (-0.00035469432)) + (-0.00012040886)) + (-0.00027512695)) + (-0.0000614502)) + (-0.0002173702)) + (-0.0002935096)) + (-0.0000875289)) + (-0.00033782847)) + (-0.00044545034)) + (-0.0002204773)) + (-0.00028807804)) + (-0.00039895778)) + (-0.0001902721)) + (-0.0004078604)) + (-0.00020329063)) + (-0.00041156492)) + (-0.000444152)) + (-0.00052273675)) + (-0.00030568673)) + (-0.00048300714)) + (-0.00027719568)) + (-0.00037226602)) + (-0.0004058566)) + (-0.00021926964)))
#     Dim var170 As Double
#     var170 = ((var18) + (var119)) + (var169)
#     Dim var171(2) As Double
#     var171(0) = (var18) / (var170)
#     var171(1) = (var119) / (var170)
#     var171(2) = (var169) / (var170)
#     pred = var171
# End Function
# End Module

# %% [markdown]
# ## Manual Scripts to convert VBA to SAS

# %%
# remove unnecessary things
code = re.sub('Dim var.* As Double', '', code)
code = re.sub('End If', '', code)

# change the beginning
code = re.sub('Module Model\nFunction pred\(ByRef inputVector\(\) As Double\) As Double\(\)\n', 
                'DATA pred_result;\nSET dataset_name;', code)

# change the ending
code = re.sub('End Function\nEnd Module\n', 'RUN;', code)

# insert ';'
all_match_list = re.findall('[0-9]+\n', code)
for idx in range(len(all_match_list)):
    original_str = all_match_list[idx]
    new_str = all_match_list[idx][:-1]+';\n'
    code = code.replace(original_str, new_str)
all_match_list = re.findall('\)\n', code)
for idx in range(len(all_match_list)):
    original_str = all_match_list[idx]
    new_str = all_match_list[idx][:-1]+';\n'
    code = code.replace(original_str, new_str)

# replace the 'inputVector' with var name
dictionary = {'inputVector(0)':'sepal_length',
              'inputVector(1)':'sepal_width',
              'inputVector(2)':'petal_length',
              'inputVector(3)':'petal_width'} 
for key in dictionary.keys():
    code = code.replace(key, dictionary[key])

# change the prediction labels
code = re.sub('Math.Exp', 'Exp', code)
code = re.sub('pred = .*\n', '', code)
temp_var_list = re.findall(r"var[0-9]+\(\d\)", code)
for var_idx in range(len(temp_var_list)):
    code = re.sub(re.sub('\\(', '\\(', re.sub('\\)', '\\)', temp_var_list[var_idx])), iris.target_names[var_idx]+'_prob', code)

# %%
print(code)
# Out:
# DATA pred_result;
# SET dataset_name;
#     If (petal_length) >= (2.45) Then
#         var0 = -0.21827246;
#     Else
#         var0 = 0.42043796;
#
#
#     If (petal_length) >= (2.45) Then
#         var1 = -0.19534391;
#     Else
#         var1 = 0.2908748;
#
#
#     If (petal_length) >= (2.45) Then
#         var2 = -0.17986836;
#     Else
#         var2 = 0.23301946;
#
#
#     If (petal_length) >= (2.45) Then
#         var3 = -0.16835201;
#     Else
#         var3 = 0.20049937;
#
#
#     If (petal_length) >= (2.45) Then
#         var4 = -0.15951659;
#     Else
#         var4 = 0.17969704;
#
#
#     If (petal_length) >= (2.45) Then
#         var5 = -0.15227905;
#     Else
#         var5 = 0.16499345;
#
#
#     If (petal_length) >= (2.45) Then
#         var6 = -0.14613919;
#     Else
#         var6 = 0.1536592;
#
#
#     If (petal_length) >= (2.45) Then
#         var7 = -0.14011411;
#     Else
#         var7 = 0.14420119;
#
#
#     If (petal_length) >= (2.45) Then
#         var8 = -0.13456865;
#     Else
#         var8 = 0.1357663;
#
#
#     If (petal_length) >= (2.45) Then
#         var9 = -0.12861697;
#     Else
#         var9 = 0.12785625;
#
#
#     If (petal_length) >= (2.45) Then
#         var10 = -0.122534;
#     Else
#         var10 = 0.120318964;
#
#
#     If (petal_length) >= (2.45) Then
#         var11 = -0.116333105;
#     Else
#         var11 = 0.112760454;
#
#
#     If (petal_length) >= (2.45) Then
#         var12 = -0.11009326;
#     Else
#         var12 = 0.10522488;
#
#
#     If (petal_length) >= (2.45) Then
#         var13 = -0.10321718;
#     Else
#         var13 = 0.09802485;
#
#
#     If (petal_length) >= (2.45) Then
#         var14 = -0.09705321;
#     Else
#         var14 = 0.09108403;
#
#
#     If (petal_length) >= (2.45) Then
#         var15 = -0.09126147;
#     Else
#         var15 = 0.08483632;
#
#
#     If (petal_length) >= (2.45) Then
#         var16 = -0.085976176;
#     Else
#         var16 = 0.08029441;
#
#
#     If (petal_length) >= (3.15) Then
#         var17 = -0.08047648;
#     Else
#         var17 = 0.074691966;
#
#
#     var18 = Exp((0.5) + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((var0) + (var1)) + (var2)) + (var3)) + (var4)) + (var5)) + (var6)) + (var7)) + (var8)) + (var9)) + (var10)) + (var11)) + (var12)) + (var13)) + (var14)) + (var15)) + (var16)) + (var17)) + (-0.005524611)) + (-0.0043015457)) + (-0.0034188137)) + (-0.002750235)) + (-0.002255812)) + (-0.0032246502)) + (-0.003928394)) + (-0.0044095414)) + (-0.004755646)) + (-0.005153919)) + (-0.005334354)) + (-0.0053935996)) + (-0.0055099125)) + (-0.005602908)) + (-0.0056739687)) + (-0.005725721)) + (-0.0057591596)) + (-0.0057757483)) + (-0.0057780943)) + (-0.0057664923)) + (-0.0057425257)) + (-0.005706845)) + (-0.005661765)) + (-0.0055862796)) + (-0.0055016503)) + (-0.005409422)) + (-0.0043303967)) + (-0.004363139)) + (-0.0043741623)) + (-0.0043655857)) + (-0.0034215322)) + (-0.0034440104)) + (-0.0034392953)) + (-0.0025525708)) + (-0.0026320452)) + (-0.0026799599)) + (-0.0018942085)) + (-0.002010829)) + (-0.0013254483)) + (-0.0014932072)) + (-0.0008871359)) + (-0.0010909127)) + (-0.00054876786)) + (-0.00077746244)) + (-0.00047311842)) + (-0.00078150653)) + (-0.0002991066)) + (-0.00053850515)) + (-0.00009780034)) + (-0.0003481089)) + (-0.000114589035)) + (0.00021802777)) + (-0.000056490986)) + (0.0003075727)) + (0.000033897595)) + (0.0003761813)) + (0.00010550783)) + (0.00039097446)) + (0.00052621064)) + (0.0002485128)) + (0.00050681765)) + (0.00024063908)) + (0.00048712498)) + (0.00059920363)) + (0.00033187374)) + (0.0005932419)) + (0.0007816312)) + (0.00049697823)) + (0.00059309823)) + (0.00077377027)) + (0.000499179)) + (0.00071924354)) + (0.00045862453)) + (0.0006752837)) + (0.00073895155)) + (0.0008862725)) + (0.0006093266)) + (0.0007892524)) + (0.00053137186)) + (0.0006919573)) + (0.0007431938)) + (0.0004984731)));
#
#     If (sepal_width) >= (2.95) Then
#         If (petal_length) >= (3.15) Then
#             If (petal_width) >= (1.7) Then
#                 var19 = -0.20412374;
#             Else
#                 var19 = 0.3122449;
#
#         Else
#             var19 = -0.210219;
#
#     Else
#         If (petal_width) >= (1.7) Then
#             var19 = -0.1894737;
#         Else
#             If (petal_length) >= (4.8500004) Then
#                 var19 = 0.12857142;
#             Else
#                 var19 = 0.4141593;
#
#
#
#
#     If (sepal_width) >= (2.95) Then
#         If (petal_length) >= (3.15) Then
#             If (petal_width) >= (1.7) Then
#                 var20 = -0.18108536;
#             Else
#                 If (sepal_length) >= (6.8) Then
#                     var20 = 0.080876015;
#                 Else
#                     var20 = 0.25359514;
#
#
#         Else
#             var20 = -0.18699098;
#
#     Else
#         If (petal_width) >= (1.7) Then
#             var20 = -0.16725719;
#         Else
#             var20 = 0.277371;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var21 = -0.17242625;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var21 = -0.03711913;
#             Else
#                 var21 = 0.24106967;
#
#         Else
#             var21 = -0.17066373;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var22 = -0.15979621;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var22 = -0.032142717;
#             Else
#                 var22 = 0.2057186;
#
#         Else
#             var22 = -0.15819389;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var23 = -0.14951265;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var23 = -0.032499813;
#             Else
#                 var23 = 0.18413201;
#
#         Else
#             var23 = -0.14792646;
#
#
#
#     If (sepal_width) >= (2.95) Then
#         If (petal_length) >= (3.15) Then
#             If (petal_length) >= (5.0) Then
#                 var24 = -0.13963485;
#             Else
#                 var24 = 0.117164016;
#
#         Else
#             var24 = -0.13886009;
#
#     Else
#         If (petal_width) >= (1.7) Then
#             var24 = -0.11100679;
#         Else
#             If (sepal_length) >= (6.25) Then
#                 var24 = 0.054723445;
#             Else
#                 var24 = 0.16924205;
#
#
#
#
#     If (petal_width) >= (1.7) Then
#         var25 = -0.1329814;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var25 = -0.036223307;
#             Else
#                 var25 = 0.15914293;
#
#         Else
#             var25 = -0.13036871;
#
#
#
#     If (sepal_width) >= (2.95) Then
#         If (petal_length) >= (3.15) Then
#             If (petal_width) >= (1.55) Then
#                 var26 = -0.11139763;
#             Else
#                 var26 = 0.11225922;
#
#         Else
#             var26 = -0.122088864;
#
#     Else
#         If (petal_width) >= (1.7) Then
#             var26 = -0.0902426;
#         Else
#             If (sepal_length) >= (6.25) Then
#                 var26 = 0.029444167;
#             Else
#                 var26 = 0.1507426;
#
#
#
#
#     If (petal_width) >= (1.7) Then
#         var27 = -0.11815263;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var27 = -0.030736469;
#             Else
#                 var27 = 0.14295922;
#
#         Else
#             var27 = -0.11385156;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var28 = -0.11094109;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var28 = -0.02325417;
#             Else
#                 var28 = 0.13578343;
#
#         Else
#             var28 = -0.10563578;
#
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (5.0) Then
#             var29 = -0.1234254;
#         Else
#             If (petal_length) >= (2.75) Then
#                 var29 = 0.09414416;
#             Else
#                 var29 = -0.09751318;
#
#
#     Else
#         var29 = 0.09731874;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (5.0) Then
#             var30 = -0.11583073;
#         Else
#             If (petal_length) >= (2.75) Then
#                 var30 = 0.08469428;
#             Else
#                 var30 = -0.0896282;
#
#
#     Else
#         var30 = 0.089641325;
#
#
#     If (petal_width) >= (1.7) Then
#         var31 = -0.092850104;
#     Else
#         If (petal_length) >= (2.45) Then
#             If (petal_length) >= (5.0) Then
#                 var31 = -0.012017109;
#             Else
#                 var31 = 0.11651696;
#
#         Else
#             var31 = -0.08211787;
#
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (5.0) Then
#             var32 = -0.10497374;
#         Else
#             If (petal_length) >= (3.8) Then
#                 var32 = 0.069721475;
#             Else
#                 var32 = -0.069488145;
#
#
#     Else
#         var32 = 0.0801942;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (5.0) Then
#             var33 = -0.09839965;
#         Else
#             If (petal_length) >= (4.25) Then
#                 var33 = 0.059869114;
#             Else
#                 var33 = -0.049647257;
#
#
#     Else
#         var33 = 0.071882054;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (5.0) Then
#             var34 = -0.09231917;
#         Else
#             var34 = 0.011245044;
#
#     Else
#         var34 = 0.06456286;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (5.0) Then
#             var35 = -0.08673477;
#         Else
#             var35 = 0.012041473;
#
#     Else
#         var35 = 0.058143985;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (4.8500004) Then
#             var36 = -0.067586765;
#         Else
#             var36 = 0.0070128157;
#
#     Else
#         var36 = 0.054344207;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (4.8500004) Then
#             var37 = -0.06299968;
#         Else
#             var37 = 0.005813309;
#
#     Else
#         var37 = 0.05105127;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (4.75) Then
#             var38 = -0.049909513;
#         Else
#             var38 = 0.0017067876;
#
#     Else
#         var38 = 0.047009006;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (4.75) Then
#             var39 = -0.045884546;
#         Else
#             var39 = -0.000008603191;
#
#     Else
#         var39 = 0.044970986;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (petal_length) >= (4.75) Then
#             var40 = -0.04232024;
#         Else
#             var40 = -0.0014069994;
#
#     Else
#         var40 = 0.04300546;
#
#
#     If (sepal_width) >= (2.75) Then
#         If (sepal_length) >= (6.25) Then
#             var41 = -0.0045899716;
#         Else
#             var41 = -0.03636634;
#
#     Else
#         var41 = 0.04110777;
#
#
#     If (sepal_width) >= (2.95) Then
#         var42 = -0.033298276;
#     Else
#         var42 = 0.03073641;
#
#
#     If (sepal_width) >= (2.75) Then
#         var43 = -0.022811672;
#     Else
#         var43 = 0.03659306;
#
#
#     If (sepal_width) >= (2.95) Then
#         var44 = -0.028586287;
#     Else
#         var44 = 0.02800061;
#
#
#     If (sepal_width) >= (2.95) Then
#         var45 = -0.02701611;
#     Else
#         var45 = 0.026413469;
#
#
#     If (sepal_width) >= (2.95) Then
#         var46 = -0.024131697;
#     Else
#         var46 = 0.024225306;
#
#
#     If (sepal_width) >= (2.95) Then
#         var47 = -0.022957405;
#     Else
#         var47 = 0.022967465;
#
#
#     If (sepal_width) >= (2.95) Then
#         var48 = -0.021356972;
#     Else
#         var48 = 0.021369683;
#
#
#     If (sepal_width) >= (2.95) Then
#         var49 = -0.020398248;
#     Else
#         var49 = 0.020367254;
#
#
#     If (sepal_width) >= (2.95) Then
#         var50 = -0.019496819;
#     Else
#         var50 = 0.01942316;
#
#
#     If (sepal_width) >= (2.95) Then
#         var51 = -0.01864721;
#     Else
#         var51 = 0.018531451;
#
#
#     If (sepal_width) >= (2.95) Then
#         var52 = -0.01784496;
#     Else
#         var52 = 0.017687792;
#
#
#     If (sepal_width) >= (2.95) Then
#         var53 = -0.017085994;
#     Else
#         var53 = 0.016888155;
#
#
#     If (sepal_width) >= (2.95) Then
#         var54 = -0.016366743;
#     Else
#         var54 = 0.016129572;
#
#
#     If (sepal_width) >= (2.95) Then
#         var55 = -0.015684122;
#     Else
#         var55 = 0.015409181;
#
#
#     If (sepal_width) >= (2.95) Then
#         var56 = -0.0150354;
#     Else
#         var56 = 0.014724416;
#
#
#     If (sepal_width) >= (2.95) Then
#         var57 = -0.014418123;
#     Else
#         var57 = 0.014073373;
#
#
#     If (sepal_width) >= (2.95) Then
#         var58 = -0.013830242;
#     Else
#         var58 = 0.013454114;
#
#
#     If (sepal_width) >= (2.95) Then
#         var59 = -0.013269678;
#     Else
#         var59 = 0.012864648;
#
#
#     If (sepal_width) >= (2.95) Then
#         var60 = -0.012643063;
#     Else
#         var60 = 0.012141587;
#
#
#     If (sepal_width) >= (2.95) Then
#         var61 = -0.01205027;
#     Else
#         var61 = 0.011471621;
#
#
#     If (petal_length) >= (4.75) Then
#         var62 = -0.010150731;
#     Else
#         var62 = 0.013071419;
#
#
#     If (sepal_width) >= (2.95) Then
#         var63 = -0.012406148;
#     Else
#         var63 = 0.011910836;
#
#
#     If (sepal_width) >= (2.95) Then
#         var64 = -0.011757467;
#     Else
#         var64 = 0.011176818;
#
#
#     If (sepal_width) >= (2.95) Then
#         var65 = -0.011150015;
#     Else
#         var65 = 0.010503451;
#
#
#     If (petal_length) >= (4.75) Then
#         var66 = -0.009147625;
#     Else
#         var66 = 0.011766563;
#
#
#     If (sepal_width) >= (2.95) Then
#         var67 = -0.011285052;
#     Else
#         var67 = 0.010670243;
#
#
#     If (sepal_width) >= (2.95) Then
#         var68 = -0.0104749445;
#     Else
#         var68 = 0.009851719;
#
#
#     If (petal_length) >= (4.75) Then
#         var69 = -0.008586614;
#     Else
#         var69 = 0.0110758655;
#
#
#     If (sepal_width) >= (2.95) Then
#         var70 = -0.010187396;
#     Else
#         var70 = 0.009699955;
#
#
#     If (sepal_width) >= (2.95) Then
#         var71 = -0.009445694;
#     Else
#         var71 = 0.008931544;
#
#
#     If (petal_length) >= (4.75) Then
#         var72 = -0.008249849;
#     Else
#         var72 = 0.010653057;
#
#
#     If (sepal_width) >= (2.95) Then
#         var73 = -0.009195565;
#     Else
#         var73 = 0.008784805;
#
#
#     If (petal_length) >= (4.75) Then
#         var74 = -0.007705495;
#     Else
#         var74 = 0.010022174;
#
#
#     If (sepal_width) >= (2.95) Then
#         var75 = -0.008920336;
#     Else
#         var75 = 0.008559105;
#
#
#     If (petal_length) >= (4.75) Then
#         var76 = -0.0072737522;
#     Else
#         var76 = 0.00948766;
#
#
#     If (sepal_width) >= (2.95) Then
#         var77 = -0.00862771;
#     Else
#         var77 = 0.008285984;
#
#
#     If (petal_length) >= (4.75) Then
#         var78 = -0.006921405;
#     Else
#         var78 = 0.009029352;
#
#
#     If (sepal_width) >= (2.95) Then
#         var79 = -0.008324347;
#     Else
#         var79 = 0.007987079;
#
#
#     If (sepal_length) >= (6.25) Then
#         var80 = -0.007871958;
#     Else
#         var80 = 0.007605633;
#
#
#     If (sepal_width) >= (2.95) Then
#         var81 = -0.0077557596;
#     Else
#         var81 = 0.0073122545;
#
#
#     If (petal_length) >= (4.75) Then
#         var82 = -0.006510421;
#     Else
#         var82 = 0.008418651;
#
#
#     If (sepal_width) >= (2.95) Then
#         var83 = -0.00777872;
#     Else
#         var83 = 0.007430695;
#
#
#     If (petal_length) >= (4.75) Then
#         var84 = -0.0062455563;
#     Else
#         var84 = 0.008077477;
#
#
#     If (sepal_width) >= (2.95) Then
#         var85 = -0.00747978;
#     Else
#         var85 = 0.0071417065;
#
#
#     If (sepal_length) >= (6.25) Then
#         var86 = -0.007054187;
#     Else
#         var86 = 0.0067576785;
#
#
#     If (petal_width) >= (1.55) Then
#         var87 = -0.007107707;
#     Else
#         var87 = 0.0063773366;
#
#
#     If (sepal_width) >= (2.95) Then
#         var88 = -0.0072453627;
#     Else
#         var88 = 0.006713987;
#
#
#     If (petal_length) >= (4.75) Then
#         var89 = -0.005951236;
#     Else
#         var89 = 0.007440034;
#
#
#     If (sepal_width) >= (2.95) Then
#         var90 = -0.0069288206;
#     Else
#         var90 = 0.006462772;
#
#
#     If (petal_length) >= (4.75) Then
#         var91 = -0.0057346295;
#     Else
#         var91 = 0.007212196;
#
#
#     If (sepal_width) >= (2.95) Then
#         var92 = -0.0066279736;
#     Else
#         var92 = 0.006210318;
#
#
#     If (petal_width) >= (1.55) Then
#         var93 = -0.006680352;
#     Else
#         var93 = 0.0059011765;
#
#
#     If (sepal_length) >= (6.25) Then
#         var94 = -0.00641546;
#     Else
#         var94 = 0.0059461687;
#
#
#     If (sepal_width) >= (2.95) Then
#         var95 = -0.0063848663;
#     Else
#         var95 = 0.0058331015;
#
#
#     If (petal_width) >= (1.55) Then
#         var96 = -0.006519892;
#     Else
#         var96 = 0.0056075505;
#
#
#     If (sepal_width) >= (2.95) Then
#         var97 = -0.0061121043;
#     Else
#         var97 = 0.0054961126;
#
#
#     If (petal_width) >= (1.55) Then
#         var98 = -0.0062804963;
#     Else
#         var98 = 0.005331184;
#
#
#     If (sepal_length) >= (6.25) Then
#         var99 = -0.00611864;
#     Else
#         var99 = 0.0055057844;
#
#
#     If (sepal_width) >= (2.95) Then
#         var100 = -0.0058476245;
#     Else
#         var100 = 0.0052049495;
#
#
#     If (petal_length) >= (4.8500004) Then
#         var101 = -0.0054073753;
#     Else
#         var101 = 0.0059557236;
#
#
#     If (petal_width) >= (1.55) Then
#         var102 = -0.005775638;
#     Else
#         var102 = 0.0048974715;
#
#
#     If (sepal_width) >= (2.95) Then
#         var103 = -0.005794904;
#     Else
#         var103 = 0.0051862155;
#
#
#     If (sepal_length) >= (6.25) Then
#         var104 = -0.0056100246;
#     Else
#         var104 = 0.0050377995;
#
#
#     If (petal_width) >= (1.55) Then
#         var105 = -0.0056587416;
#     Else
#         var105 = 0.0047248425;
#
#
#     If (sepal_width) >= (2.95) Then
#         var106 = -0.005509358;
#     Else
#         var106 = 0.0048817163;
#
#
#     If (petal_length) >= (4.8500004) Then
#         var107 = -0.0049915086;
#     Else
#         var107 = 0.0054499186;
#
#
#     If (sepal_width) >= (2.95) Then
#         var108 = -0.0052451305;
#     Else
#         var108 = 0.0047048037;
#
#
#     If (petal_length) >= (4.8500004) Then
#         var109 = -0.0048227385;
#     Else
#         var109 = 0.0053271577;
#
#
#     If (sepal_length) >= (6.25) Then
#         var110 = -0.005009591;
#     Else
#         var110 = 0.0045543583;
#
#
#     If (petal_width) >= (1.55) Then
#         var111 = -0.0052086543;
#     Else
#         var111 = 0.0043845773;
#
#
#     If (sepal_width) >= (2.95) Then
#         var112 = -0.005186406;
#     Else
#         var112 = 0.0046561235;
#
#
#     If (petal_length) >= (4.8500004) Then
#         var113 = -0.004448584;
#     Else
#         var113 = 0.004879616;
#
#
#     If (sepal_width) >= (2.95) Then
#         var114 = -0.0049228747;
#     Else
#         var114 = 0.0044552675;
#
#
#     If (petal_width) >= (1.55) Then
#         var115 = -0.0050548674;
#     Else
#         var115 = 0.0042359494;
#
#
#     If (sepal_length) >= (6.25) Then
#         var116 = -0.0047040326;
#     Else
#         var116 = 0.004205803;
#
#
#     If (sepal_width) >= (2.95) Then
#         var117 = -0.0046814047;
#     Else
#         var117 = 0.004182419;
#
#
#     If (petal_length) >= (4.8500004) Then
#         var118 = -0.0043212525;
#     Else
#         var118 = 0.004731095;
#
#
#     var119 = Exp((0.5) + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((var19) + (var20)) + (var21)) + (var22)) + (var23)) + (var24)) + (var25)) + (var26)) + (var27)) + (var28)) + (var29)) + (var30)) + (var31)) + (var32)) + (var33)) + (var34)) + (var35)) + (var36)) + (var37)) + (var38)) + (var39)) + (var40)) + (var41)) + (var42)) + (var43)) + (var44)) + (var45)) + (var46)) + (var47)) + (var48)) + (var49)) + (var50)) + (var51)) + (var52)) + (var53)) + (var54)) + (var55)) + (var56)) + (var57)) + (var58)) + (var59)) + (var60)) + (var61)) + (var62)) + (var63)) + (var64)) + (var65)) + (var66)) + (var67)) + (var68)) + (var69)) + (var70)) + (var71)) + (var72)) + (var73)) + (var74)) + (var75)) + (var76)) + (var77)) + (var78)) + (var79)) + (var80)) + (var81)) + (var82)) + (var83)) + (var84)) + (var85)) + (var86)) + (var87)) + (var88)) + (var89)) + (var90)) + (var91)) + (var92)) + (var93)) + (var94)) + (var95)) + (var96)) + (var97)) + (var98)) + (var99)) + (var100)) + (var101)) + (var102)) + (var103)) + (var104)) + (var105)) + (var106)) + (var107)) + (var108)) + (var109)) + (var110)) + (var111)) + (var112)) + (var113)) + (var114)) + (var115)) + (var116)) + (var117)) + (var118)));
#
#     If (petal_width) >= (1.7) Then
#         var120 = 0.42206898;
#     Else
#         If (petal_length) >= (5.0) Then
#             var120 = 0.12857142;
#         Else
#             var120 = -0.21779363;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var121 = 0.29245776;
#     Else
#         If (petal_length) >= (5.0) Then
#             var121 = 0.11548449;
#         Else
#             var121 = -0.19506966;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var122 = 0.23459488;
#     Else
#         If (petal_length) >= (5.0) Then
#             var122 = 0.110459164;
#         Else
#             var122 = -0.17962503;
#
#
#
#     If (petal_length) >= (4.75) Then
#         If (petal_width) >= (1.7) Then
#             var123 = 0.20165354;
#         Else
#             If (sepal_length) >= (6.55) Then
#                 var123 = 0.035918195;
#             Else
#                 var123 = -0.002120249;
#
#
#     Else
#         var123 = -0.16714881;
#
#
#     If (petal_length) >= (4.75) Then
#         If (petal_width) >= (1.7) Then
#             var124 = 0.1806804;
#         Else
#             If (sepal_length) >= (6.55) Then
#                 var124 = 0.03683346;
#             Else
#                 var124 = -0.0038339198;
#
#
#     Else
#         var124 = -0.15801106;
#
#
#     If (petal_length) >= (4.75) Then
#         If (petal_width) >= (1.7) Then
#             var125 = 0.16593829;
#         Else
#             var125 = 0.019427221;
#
#     Else
#         var125 = -0.15039223;
#
#
#     If (petal_length) >= (4.75) Then
#         If (petal_width) >= (1.7) Then
#             var126 = 0.15514049;
#         Else
#             var126 = 0.018677209;
#
#     Else
#         var126 = -0.14384772;
#
#
#     If (petal_length) >= (4.75) Then
#         If (sepal_width) >= (2.75) Then
#             If (petal_length) >= (5.0) Then
#                 var127 = 0.1629031;
#             Else
#                 var127 = 0.014899884;
#
#         Else
#             var127 = -0.0037306617;
#
#     Else
#         var127 = -0.13729754;
#
#
#     If (petal_length) >= (4.75) Then
#         If (sepal_width) >= (2.75) Then
#             var128 = 0.1353838;
#         Else
#             var128 = -0.0062334556;
#
#     Else
#         var128 = -0.1311339;
#
#
#     If (petal_length) >= (4.8500004) Then
#         If (sepal_width) >= (2.75) Then
#             var129 = 0.13454688;
#         Else
#             var129 = -0.011915565;
#
#     Else
#         var129 = -0.11783707;
#
#
#     If (petal_width) >= (1.7) Then
#         var130 = 0.12492787;
#     Else
#         If (petal_length) >= (5.0) Then
#             var130 = 0.036514416;
#         Else
#             var130 = -0.123543926;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var131 = 0.1185313;
#     Else
#         If (sepal_length) >= (6.25) Then
#             var131 = 0.020319015;
#         Else
#             var131 = -0.1256014;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var132 = 0.1124286;
#     Else
#         If (petal_length) >= (5.0) Then
#             var132 = 0.028851861;
#         Else
#             var132 = -0.1117734;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var133 = 0.10507546;
#     Else
#         If (sepal_length) >= (6.25) Then
#             var133 = 0.025969665;
#         Else
#             var133 = -0.11468511;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var134 = 0.09938078;
#     Else
#         If (sepal_length) >= (6.25) Then
#             var134 = 0.022141764;
#         Else
#             var134 = -0.10712744;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var135 = 0.094023526;
#     Else
#         If (sepal_length) >= (6.25) Then
#             var135 = 0.018630145;
#         Else
#             var135 = -0.100098945;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var136 = 0.088826604;
#     Else
#         If (petal_length) >= (5.0) Then
#             var136 = 0.02379664;
#         Else
#             var136 = -0.09160408;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var137 = 0.08399659;
#     Else
#         If (petal_length) >= (5.0) Then
#             var137 = 0.0198199;
#         Else
#             var137 = -0.08659977;
#
#
#
#     If (petal_width) >= (1.7) Then
#         var138 = 0.07945747;
#     Else
#         If (sepal_length) >= (6.25) Then
#             var138 = 0.014234061;
#         Else
#             var138 = -0.086219266;
#
#
#
#     If (petal_length) >= (4.95) Then
#         var139 = 0.056224484;
#     Else
#         var139 = -0.05822058;
#
#
#     If (petal_length) >= (4.95) Then
#         var140 = 0.051960308;
#     Else
#         var140 = -0.05478737;
#
#
#     If (petal_length) >= (4.95) Then
#         var141 = 0.048160266;
#     Else
#         var141 = -0.051507387;
#
#
#     If (petal_length) >= (4.95) Then
#         var142 = 0.044765294;
#     Else
#         var142 = -0.048380338;
#
#
#     If (sepal_length) >= (6.1499996) Then
#         var143 = 0.042006496;
#     Else
#         var143 = -0.048374478;
#
#
#     If (petal_length) >= (4.95) Then
#         var144 = 0.04312884;
#     Else
#         var144 = -0.04476531;
#
#
#     If (petal_length) >= (4.95) Then
#         var145 = 0.040548287;
#     Else
#         var145 = -0.042045474;
#
#
#     If (sepal_length) >= (6.1499996) Then
#         var146 = 0.03782676;
#     Else
#         var146 = -0.042320237;
#
#
#     If (petal_length) >= (4.95) Then
#         var147 = 0.03899815;
#     Else
#         var147 = -0.038873903;
#
#
#     If (petal_width) >= (1.55) Then
#         var148 = 0.03592317;
#     Else
#         var148 = -0.038325332;
#
#
#     If (petal_length) >= (4.95) Then
#         var149 = 0.03611918;
#     Else
#         var149 = -0.035577055;
#
#
#     If (petal_length) >= (4.95) Then
#         var150 = 0.03423064;
#     Else
#         var150 = -0.03313821;
#
#
#     If (petal_length) >= (4.95) Then
#         var151 = 0.03245664;
#     Else
#         var151 = -0.03086154;
#
#
#     If (petal_length) >= (4.95) Then
#         var152 = 0.030789543;
#     Else
#         var152 = -0.028738016;
#
#
#     If (petal_length) >= (4.95) Then
#         var153 = 0.029221699;
#     Else
#         var153 = -0.026758851;
#
#
#     If (petal_length) >= (4.95) Then
#         var154 = 0.027746823;
#     Else
#         var154 = -0.024915457;
#
#
#     If (petal_length) >= (4.95) Then
#         var155 = 0.026358254;
#     Else
#         var155 = -0.023199474;
#
#
#     If (petal_length) >= (4.95) Then
#         var156 = 0.025050567;
#     Else
#         var156 = -0.021602811;
#
#
#     If (petal_length) >= (4.95) Then
#         var157 = 0.023818111;
#     Else
#         var157 = -0.020117808;
#
#
#     If (petal_length) >= (4.95) Then
#         var158 = 0.022655703;
#     Else
#         var158 = -0.01873721;
#
#
#     If (petal_length) >= (4.95) Then
#         var159 = 0.021558635;
#     Else
#         var159 = -0.017453903;
#
#
#     If (petal_length) >= (5.05) Then
#         var160 = 0.01705505;
#     Else
#         var160 = -0.011839308;
#
#
#     If (petal_length) >= (5.05) Then
#         var161 = 0.016322859;
#     Else
#         var161 = -0.01097905;
#
#
#     If (petal_length) >= (5.05) Then
#         var162 = 0.015618752;
#     Else
#         var162 = -0.010186777;
#
#
#     If (petal_length) >= (4.95) Then
#         var163 = 0.018722648;
#     Else
#         var163 = -0.014093797;
#
#
#     If (petal_length) >= (5.05) Then
#         var164 = 0.0128751155;
#     Else
#         var164 = -0.008817958;
#
#
#     If (petal_length) >= (5.05) Then
#         var165 = 0.012440304;
#     Else
#         var165 = -0.008168368;
#
#
#     If (petal_length) >= (5.05) Then
#         var166 = 0.012007318;
#     Else
#         var166 = -0.0075733773;
#
#
#     If (petal_length) >= (5.05) Then
#         var167 = 0.011578177;
#     Else
#         var167 = -0.0070278803;
#
#
#     If (petal_length) >= (4.95) Then
#         var168 = 0.013901628;
#     Else
#         var168 = -0.013933337;
#
#
#     var169 = Exp((0.5) + ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((var120) + (var121)) + (var122)) + (var123)) + (var124)) + (var125)) + (var126)) + (var127)) + (var128)) + (var129)) + (var130)) + (var131)) + (var132)) + (var133)) + (var134)) + (var135)) + (var136)) + (var137)) + (var138)) + (var139)) + (var140)) + (var141)) + (var142)) + (var143)) + (var144)) + (var145)) + (var146)) + (var147)) + (var148)) + (var149)) + (var150)) + (var151)) + (var152)) + (var153)) + (var154)) + (var155)) + (var156)) + (var157)) + (var158)) + (var159)) + (var160)) + (var161)) + (var162)) + (var163)) + (var164)) + (var165)) + (var166)) + (var167)) + (0.0020890676)) + (0.002167549)) + (0.0022100194)) + (0.0014535759)) + (0.0015829625)) + (0.001671069)) + (0.0010004609)) + (0.00115871)) + (0.00058170274)) + (0.0007864849)) + (0.00027943132)) + (0.00051410426)) + (0.000060563903)) + (0.00031364217)) + (var168)) + (0.00036175954)) + (-0.000050552477)) + (0.0001988802)) + (-0.00017846926)) + (0.000077999415)) + (-0.000043270826)) + (-0.00022329079)) + (0.000023552982)) + (-0.00031417116)) + (-0.00006350542)) + (-0.0003788344)) + (-0.00012786238)) + (-0.000285355)) + (-0.00035469432)) + (-0.00012040886)) + (-0.00027512695)) + (-0.0000614502)) + (-0.0002173702)) + (-0.0002935096)) + (-0.0000875289)) + (-0.00033782847)) + (-0.00044545034)) + (-0.0002204773)) + (-0.00028807804)) + (-0.00039895778)) + (-0.0001902721)) + (-0.0004078604)) + (-0.00020329063)) + (-0.00041156492)) + (-0.000444152)) + (-0.00052273675)) + (-0.00030568673)) + (-0.00048300714)) + (-0.00027719568)) + (-0.00037226602)) + (-0.0004058566)) + (-0.00021926964)));
#
#     var170 = ((var18) + (var119)) + (var169);
#
#     setosa_prob = (var18) / (var170);
#     versicolor_prob = (var119) / (var170);
#     virginica_prob = (var169) / (var170);
#     RUN;

# %%
# save output
vb = open('vb1.sas', 'w')
vb.write(code)
vb.close()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
col_names = ['sepal_length','sepal_width','petal_length','petal_width']

# %%
pd.DataFrame(X_test, columns = col_names).to_csv('iris_test.csv',index=False)

# %% [markdown]
# ## Compare prediction output

# %%
# python pred
python_pred = pd.DataFrame(model.predict_proba(X_test))
python_pred.columns = ['setosa_prob','versicolor_prob','virginica_prob']
python_pred
# Out:
#     setosa_prob  versicolor_prob  virginica_prob
# 0      0.001542         0.000793        0.997665
# 1      0.890853         0.107015        0.002132
# 2      0.012138         0.982334        0.005527
# 3      0.003852         0.992223        0.003925
# 4      0.002903         0.995775        0.001322
# 5      0.009590         0.795294        0.195116
# 6      0.002376         0.022084        0.975540
# 7      0.001774         0.997418        0.000808
# 8      0.990309         0.007320        0.002371
# 9      0.990309         0.007320        0.002371
# 10     0.001542         0.000793        0.997665
# 11     0.035152         0.450551        0.514297
# 12     0.990309         0.007320        0.002371
# 13     0.009466         0.053366        0.937168
# 14     0.002799         0.028248        0.968953
# 15     0.990309         0.007320        0.002371
# 16     0.001774         0.997418        0.000808
# 17     0.011382         0.977018        0.011599
# 18     0.001539         0.002620        0.995841
# 19     0.731802         0.266447        0.001752
# 20     0.990309         0.007320        0.002371
# 21     0.009270         0.768827        0.221903
# 22     0.011536         0.025406        0.963058
# 23     0.990309         0.007320        0.002371
# 24     0.001542         0.000793        0.997665
# 25     0.012138         0.982334        0.005527
# 26     0.014817         0.977916        0.007267
# 27     0.001814         0.000933        0.997254
# 28     0.990309         0.007320        0.002371
# 29     0.990309         0.007320        0.002371
# 30     0.001542         0.000793        0.997665
# 31     0.990309         0.007320        0.002371
# 32     0.990309         0.007320        0.002371
# 33     0.990309         0.007320        0.002371
# 34     0.001542         0.000793        0.997665
# 35     0.990309         0.007320        0.002371
# 36     0.990309         0.007320        0.002371
# 37     0.001774         0.997418        0.000808
# 38     0.990309         0.007320        0.002371
# 39     0.003275         0.033050        0.963675
# 40     0.990309         0.007320        0.002371
# 41     0.001542         0.000793        0.997665
# 42     0.012138         0.982334        0.005527
# 43     0.990309         0.007320        0.002371
# 44     0.002902         0.995531        0.001567

# %%
# sas pred
sas_pred = pd.read_csv('pred_result.csv')
sas_pred = sas_pred.iloc[:,-3:]
sas_pred
# Out:
#     setosa_prob  versicolor_prob  virginica_prob
# 0      0.001542         0.000793        0.997665
# 1      0.890853         0.107015        0.002132
# 2      0.012138         0.982334        0.005527
# 3      0.003852         0.992223        0.003925
# 4      0.002903         0.995775        0.001322
# 5      0.009590         0.795294        0.195116
# 6      0.002376         0.022084        0.975540
# 7      0.001774         0.997418        0.000808
# 8      0.990309         0.007320        0.002371
# 9      0.990309         0.007320        0.002371
# 10     0.001542         0.000793        0.997665
# 11     0.035152         0.450551        0.514297
# 12     0.990309         0.007320        0.002371
# 13     0.009466         0.053366        0.937168
# 14     0.002799         0.028248        0.968953
# 15     0.990309         0.007320        0.002371
# 16     0.001774         0.997418        0.000808
# 17     0.011382         0.977018        0.011599
# 18     0.001539         0.002620        0.995841
# 19     0.731802         0.266447        0.001752
# 20     0.990309         0.007320        0.002371
# 21     0.009270         0.768827        0.221903
# 22     0.011536         0.025406        0.963058
# 23     0.990309         0.007320        0.002371
# 24     0.001542         0.000793        0.997665
# 25     0.012138         0.982334        0.005527
# 26     0.014817         0.977916        0.007267
# 27     0.001814         0.000933        0.997254
# 28     0.990309         0.007320        0.002371
# 29     0.990309         0.007320        0.002371
# 30     0.001542         0.000793        0.997665
# 31     0.990309         0.007320        0.002371
# 32     0.990309         0.007320        0.002371
# 33     0.990309         0.007320        0.002371
# 34     0.001542         0.000793        0.997665
# 35     0.990309         0.007320        0.002371
# 36     0.990309         0.007320        0.002371
# 37     0.001774         0.997418        0.000808
# 38     0.990309         0.007320        0.002371
# 39     0.003275         0.033050        0.963675
# 40     0.990309         0.007320        0.002371
# 41     0.001542         0.000793        0.997665
# 42     0.012138         0.982334        0.005527
# 43     0.990309         0.007320        0.002371
# 44     0.002902         0.995531        0.001567

# %%
(abs(python_pred - sas_pred) > 0.00001).sum()
# Out:
# setosa_prob        0
# versicolor_prob    0
# virginica_prob     0
# dtype: int64
